# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, label='plot1')
plt.plot(x,z, label='plot2')
plt.xlabel('a label')
plt.ylabel('b label')
plt.title(" Two plots")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,y)
ax1.set_title('PLOT 1')   
ax1.set_xlabel('a label')     
ax1.set_ylabel('b label')   

ax2.plot(x,z)
ax2.set_title('PLOT 2')
ax2.set_xlabel('a label')
ax2.set_ylabel('b label')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2,facecolor='green', figsize=[10,5])
ax1.plot(x,y)
ax1.set_title('PLOT 1')   
ax1.set_xlabel('a label')     
ax1.set_ylabel('b label')   

ax2.plot(x,z)
ax2.set_title('PLOT 2')
ax2.set_xlabel('a label')
ax2.set_ylabel('b label')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
plt.plot(x, x**2, label='plot1')
plt.plot(x,np.exp(x), label='plot2')
plt.xlabel('a label')
plt.ylabel('b label')
plt.title(" Two plots")
plt.legend()
plt.show()

# %%
# your code here

fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,x**2)
ax1.set_title('PLOT 1')   
ax1.set_xlabel('a label')     
ax1.set_ylabel('b label')   

ax2.plot(x,np.exp(x))
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_title('PLOT 2')
ax2.set_xlabel('a label')
ax2.set_ylabel('b label')


plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit2 = pd.read_csv(r'C:\Users\ouykh\Downloads\Fitbit2.csv\Fitbit2.csv')
fitbit2.head(2)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# 0               1680  ...        0.403891    Friday           4.0
# 1               2248  ...        8.767545  Saturday           5.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# 0                1     6.400000        92.086331              0.0
# 1                0     7.566667        92.464358              6.4
#
#    Yesterday_sleep_efficiency  Months  Months_encoded
# 0                    0.000000     May               5
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
#
# * Save your figures in a folder called `figures` in your repo.

# %%
# your code here

#fitbit2.sort_values(by=["","",""],inplace=True)
#plt.plot(Steps, Months_encoded, label='by month')
fitbit2_month = fitbit2[["Months_encoded","Steps"]].groupby(["Months_encoded"]).agg("median")
fitbit2_month.plot.bar(figsize=[12,4])
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
fitbit2_week = fitbit2[["Steps","Work_or_Weekend"]].groupby(["Work_or_Weekend"]).agg("median")
fitbit2_week.plot.barh(figsize=[12,4])
# Out:
# <AxesSubplot:ylabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
    
x_col = "Steps"
y_columns = ["Minutes Sedentary","Minutes Lightly Active","Minutes Very Active"]


for y_col in y_columns:

    figure = plt.figure
    ax = plt.gca()
    ax.scatter(fitbit2[x_col], fitbit2[y_col])
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    ax.set_title("{} vs {}".format(x_col, y_col))

    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv(r'C:\Users\ouykh\Downloads\titanic.csv\titanic.csv')
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500    U0        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_var = titanic.select_dtypes(include=numerics)
num_var
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
cat_var = titanic.select_dtypes(exclude=numerics)
cat_var
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
figsize=[12,4]

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

titanic["Age"] = titanic["Age"].astype(int)
# better use round
titanic_age = titanic[["Age"]].groupby(["Age"]).size()
titanic_age.plot.bar()
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

f, axarr = plt.subplots(3, sharex=True, sharey=True)

axarr[0].hist(titanic_age, range = (0,10)); # range parameter set the start and the end of the bin
axarr[0].set_title('Bin equal to 10')
axarr[1].hist(titanic_age, range = (10,20));
axarr[1].set_title('Bin equal to 10 to 20')
axarr[2].hist(titanic_age, range = (20,50));
axarr[2].set_title('Bin equal to 20 to 50')
# Out:
# Text(0.5, 1.0, 'Bin equal to 20 to 50')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here 

the plots is "responsive" as it fit to the bin size
but there are empty ranges
"""
# Out:
# '\nyour comments here \n\nthe plots is "responsive" as it fit to the bin size\nbut there are empty ranges\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.scatterplot(x="Age", y=titanic_age, data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

titanic_gender= titanic[["Gender"]].groupby(["Gender"]).size()
titanic_gender
# Out:
# Gender
# female    466
# male      843
# dtype: int64

# %%
labels = ['female', 'male']
sizes = [466, 843]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%')
ax1.axis('equal')
plt.show()

# %%
# Method 2 - seaborn
# your code here
#sns.barplot(x="day", y="total_bill", data=tips)

sns.countplot(data=titanic, x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(data=titanic, x='Pclass')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(x='Gender',y='Age',data=titanic, palette='rainbow')
plt.title("Age by Passenger Gender, Titanic")
# Out:
# Text(0.5, 1.0, 'Age by Passenger Gender, Titanic')

# %%
sns.violinplot(x='Gender',y="Age",data=titanic, hue='Pclass', palette='rainbow')
plt.title("Violin Plot of Age by Gender, Separated by Pclass")
# Out:
# Text(0.5, 1.0, 'Violin Plot of Age by Gender, Separated by Pclass')

# %%
"""
your comments here
Second plot shows 3 dimensions but it is more complicated to analyse 
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here

the most frequent age range is 20 to 40 
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

y = titanic['Fare'].values
x = titanic['Age'].values
plt.scatter(x,y)
plt.show()

# %%
# Method 2 - seaborn
# your code here
plt.figure(figsize=(12,8))
sns.stripplot(x='Age', y='Fare', data=titanic, palette='viridis')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
titanic.corr()
sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
sibsp Number of Siblings/Spouses Aboard
parch Number of Parents/Children Aboard
there are both related to family. There are good probability that all the family members travel together 

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x='Pclass',y='Age',data=titanic, palette='rainbow')
plt.title("Age by Passenger Pclass, Titanic")
# Out:
# Text(0.5, 1.0, 'Age by Passenger Pclass, Titanic')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
# not working
a = sns.FacetGrid(titanic, col="Gender", row="Age")
a.map_dataframe(sns.histplot, x="Age")
