# %%
import pandas as pd

# %%
df= pd.DataFrame([(1,231,'Self-employed','009','High',2,30200),
    (2,765,'students','005','high',3,12700),
    (3,453,'Horeca','007','medium',5,89400),
    (4,231,'self-employed','009','high',2,30200),
    (5,892,'finance','003','low',3,740000)],
    columns= ("TransactionID","ClientID","Profession","Bank_dep","Risk","Number of credits","Revenue",))
df
# Out:
#    TransactionID  ClientID     Profession Bank_dep    Risk  Number of credits  \
# 0              1       231  Self-employed      009    High                  2
# 1              2       765       students      005    high                  3
# 2              3       453         Horeca      007  medium                  5
# 3              4       231  self-employed      009    high                  2
# 4              5       892        finance      003     low                  3
#
#    Revenue
# 0    30200
# 1    12700
# 2    89400
# 3    30200
# 4   740000

# %%
z = pd.get_dummies(df.Profession, prefix='Profession')
z
# Out:
#    Profession_Horeca  Profession_Self-employed  Profession_finance  \
# 0                  0                         1                   0
# 1                  0                         0                   0
# 2                  1                         0                   0
# 3                  0                         0                   0
# 4                  0                         0                   1
#
#    Profession_self-employed  Profession_students
# 0                         0                    0
# 1                         0                    1
# 2                         0                    0
# 3                         1                    0
# 4                         0                    0

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df2= df["Profession"] = label.fit_transform(df["Profession"])
df2
# Out:
# array([1, 4, 0, 3, 2], dtype=int64)

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
enc.fit(df[["Risk"]])
df[["Risk"]] = enc.transform(df[["Risk"]])
df
# Out:
#    TransactionID  ClientID     Profession Bank_dep  Risk  Number of credits  \
# 0              1       231  Self-employed      009   0.0                  2
# 1              2       765       students      005   1.0                  3
# 2              3       453         Horeca      007   3.0                  5
# 3              4       231  self-employed      009   1.0                  2
# 4              5       892        finance      003   2.0                  3
#
#    Revenue
# 0    30200
# 1    12700
# 2    89400
# 3    30200
# 4   740000
